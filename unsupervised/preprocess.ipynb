# %%
import pandas as pd
import os

# %%
path = os.getcwd() + '/data/'

# %%
df = pd.read_csv(path +'yearly_full_release_long_format.csv')

# %%
df
# Out:
#                Area Country code  Year Area type Continent Ember region   EU  \
# 0       Afghanistan          AFG  2000   Country      Asia         Asia  0.0
# 1       Afghanistan          AFG  2000   Country      Asia         Asia  0.0
# 2       Afghanistan          AFG  2000   Country      Asia         Asia  0.0
# 3       Afghanistan          AFG  2000   Country      Asia         Asia  0.0
# 4       Afghanistan          AFG  2000   Country      Asia         Asia  0.0
# ...             ...          ...   ...       ...       ...          ...  ...
# 345025     Zimbabwe          ZWE  2022   Country    Africa       Africa  0.0
# 345026     Zimbabwe          ZWE  2022   Country    Africa       Africa  0.0
# 345027     Zimbabwe          ZWE  2022   Country    Africa       Africa  0.0
# 345028     Zimbabwe          ZWE  2022   Country    Africa       Africa  0.0
# 345029     Zimbabwe          ZWE  2022   Country    Africa       Africa  0.0
#
# ...

# %%
df.isnull().values.any()
# Out:
# np.True_

# %%
df = df.dropna()

# %%
df
# Out:
#                Area Country code  Year Area type Continent Ember region   EU  \
# 66      Afghanistan          AFG  2001   Country      Asia         Asia  0.0
# 67      Afghanistan          AFG  2001   Country      Asia         Asia  0.0
# 68      Afghanistan          AFG  2001   Country      Asia         Asia  0.0
# 69      Afghanistan          AFG  2001   Country      Asia         Asia  0.0
# 70      Afghanistan          AFG  2001   Country      Asia         Asia  0.0
# ...             ...          ...   ...       ...       ...          ...  ...
# 345017     Zimbabwe          ZWE  2022   Country    Africa       Africa  0.0
# 345019     Zimbabwe          ZWE  2022   Country    Africa       Africa  0.0
# 345021     Zimbabwe          ZWE  2022   Country    Africa       Africa  0.0
# 345023     Zimbabwe          ZWE  2022   Country    Africa       Africa  0.0
# 345029     Zimbabwe          ZWE  2022   Country    Africa       Africa  0.0
#
# ...

# %%
df.describe()
# Out:
#                 Year             EU           OECD           G20  \
# count  142414.000000  142414.000000  142414.000000  142414.00000
# mean     2012.279376       0.182945       0.264244       0.13722
# std         6.501350       0.386623       0.440931       0.34408
# min      2001.000000       0.000000       0.000000       0.00000
# 25%      2007.000000       0.000000       0.000000       0.00000
# 50%      2013.000000       0.000000       0.000000       0.00000
# 75%      2018.000000       0.000000       1.000000       0.00000
# max      2023.000000       1.000000       1.000000       1.00000
#
#                   G7          ASEAN          Value  YoY absolute change  \
# count  142414.000000  142414.000000  142414.000000        142414.000000
# mean        0.054594       0.053394      42.064296             0.724455
# std         0.227188       0.224818     211.868234            13.901412
# min         0.000000       0.000000     -50.340000          -500.000000
# ...

# %%
df.to_csv(path+'preprocessed.csv')
